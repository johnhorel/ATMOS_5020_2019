# %%
import xarray
import matplotlib.pyplot as plt
import numpy as np

# %%
FILE = './data/OR_ABI-L2-MCMIPC-M6_G17_s20192621856196_e20192621858575_c20192621859089.nc'
C = xarray.open_dataset(FILE)

# %%
C.band_wavelength_C01.data[0]
# Out:
# 0.47

# %%
C['CMI_C01'].plot()

# %%
C.summary
# Out:
# 'Multiple reflectance and emissive channel Cloud and Moisture Imagery Products are digital maps of clouds, moisture, and atmospheric windows at visible, near-IR, and IR bands.'
